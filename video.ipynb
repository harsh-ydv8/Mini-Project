# %%
import cv2 
import numpy as np 
from skimage.filters import threshold_local 
import tensorflow as tf 
from skimage import measure 
import imutils 
import os
# Out:
# WARNING:tensorflow:From c:\Users\harsh\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
def sort_cont(contours):
    """
    Sort contours from left to right based on the x-coordinate of their bounding boxes.

    :param contours: List of contour points.
    :return: Sorted list of contours.
    """
    # Generate bounding boxes for each contour and sort them by x-coordinate
    bounding_boxes = [cv2.boundingRect(contour) for contour in contours]
    sorted_contours = sorted(zip(contours, bounding_boxes), key=lambda b: b[1][0])
    return [contour for contour, _ in sorted_contours]

# %%
def segment_chars(plate_img, fixed_width): 
	
	""" 
	extract Value channel from the HSV format 
	of image and apply adaptive thresholding 
	to reveal the characters on the license plate 
	"""
	V = cv2.split(cv2.cvtColor(plate_img, cv2.COLOR_BGR2HSV))[2] 

	thresh = cv2.adaptiveThreshold(V, 255, 
								cv2.ADAPTIVE_THRESH_GAUSSIAN_C, 
								cv2.THRESH_BINARY, 
								11, 2) 
	
	thresh = cv2.bitwise_not(thresh) 

	# resize the license plate region to 
	# a canoncial size 
	plate_img = imutils.resize(plate_img, width = fixed_width) 
	thresh = imutils.resize(thresh, width = fixed_width) 
	bgr_thresh = cv2.cvtColor(thresh, cv2.COLOR_GRAY2BGR) 

	# perform a connected components analysis 
	# and initialize the mask to store the locations 
	# of the character candidates 
	labels = measure.label(thresh, background = 0) 

	charCandidates = np.zeros(thresh.shape, dtype ='uint8') 

	# loop over the unique components 
	characters = [] 
	for label in np.unique(labels): 
		
		# if this is the background label, ignore it 
		if label == 0: 
			continue
		# otherwise, construct the label mask to display 
		# only connected components for the current label, 
		# then find contours in the label mask 
		labelMask = np.zeros(thresh.shape, dtype ='uint8') 
		labelMask[labels == label] = 255

		cnts = cv2.findContours(labelMask, 
					cv2.RETR_EXTERNAL, 
					cv2.CHAIN_APPROX_SIMPLE) 

		cnts = cnts[1] if imutils.is_cv3() else cnts[0] 

		# ensure at least one contour was found in the mask 
		if len(cnts) > 0: 

			# grab the largest contour which corresponds 
			# to the component in the mask, then grab the 
			# bounding box for the contour 
			c = max(cnts, key = cv2.contourArea) 
			(boxX, boxY, boxW, boxH) = cv2.boundingRect(c) 

			# compute the aspect ratio, solodity, and 
			# height ration for the component 
			aspectRatio = boxW / float(boxH) 
			solidity = cv2.contourArea(c) / float(boxW * boxH) 
			heightRatio = boxH / float(plate_img.shape[0]) 

			# determine if the aspect ratio, solidity, 
			# and height of the contour pass the rules 
			# tests 
			keepAspectRatio = aspectRatio < 1.0
			keepSolidity = solidity > 0.15
			keepHeight = heightRatio > 0.5 and heightRatio < 0.95

			# check to see if the component passes 
			# all the tests 
			if keepAspectRatio and keepSolidity and keepHeight and boxW > 14: 
				
				# compute the convex hull of the contour 
				# and draw it on the character candidates 
				# mask 
				hull = cv2.convexHull(c) 

				cv2.drawContours(charCandidates, [hull], -1, 255, -1) 

	contours, hier = cv2.findContours(charCandidates, 
										cv2.RETR_EXTERNAL, 
										cv2.CHAIN_APPROX_SIMPLE) 
	
	if contours: 
		contours = sort_cont(contours) 
		
		# value to be added to each dimension 
		# of the character 
		addPixel = 4
		for c in contours: 
			(x, y, w, h) = cv2.boundingRect(c) 
			if y > addPixel: 
				y = y - addPixel 
			else: 
				y = 0
			if x > addPixel: 
				x = x - addPixel 
			else: 
				x = 0
			temp = bgr_thresh[y:y + h + (addPixel * 2), 
							x:x + w + (addPixel * 2)] 

			characters.append(temp) 
			
		return characters 
	
	else: 
		return None

# %%
class PlateFinder: 
	def __init__(self, minPlateArea, maxPlateArea): 
		
		# minimum area of the plate 
		self.min_area = minPlateArea 
		
		# maximum area of the plate 
		self.max_area = maxPlateArea 

		self.element_structure = cv2.getStructuringElement( 
							shape = cv2.MORPH_RECT, ksize =(22, 3)) 

	def preprocess(self, input_img): 
		
		imgBlurred = cv2.GaussianBlur(input_img, (7, 7), 0) 
		
		# convert to gray 
		gray = cv2.cvtColor(imgBlurred, cv2.COLOR_BGR2GRAY) 
		
		# sobelX to get the vertical edges 
		sobelx = cv2.Sobel(gray, cv2.CV_8U, 1, 0, ksize = 3) 
		
		# otsu's thresholding 
		ret2, threshold_img = cv2.threshold(sobelx, 0, 255, 
						cv2.THRESH_BINARY + cv2.THRESH_OTSU) 

		element = self.element_structure 
		morph_n_thresholded_img = threshold_img.copy() 
		cv2.morphologyEx(src = threshold_img, 
						op = cv2.MORPH_CLOSE, 
						kernel = element, 
						dst = morph_n_thresholded_img) 
		
		return morph_n_thresholded_img 

	def extract_contours(self, after_preprocess): 
		
		contours, _ = cv2.findContours(after_preprocess, 
										mode = cv2.RETR_EXTERNAL, 
										method = cv2.CHAIN_APPROX_NONE) 
		return contours 

	def clean_plate(self, plate): 
		
		gray = cv2.cvtColor(plate, cv2.COLOR_BGR2GRAY) 
		thresh = cv2.adaptiveThreshold(gray, 
									255, 
									cv2.ADAPTIVE_THRESH_GAUSSIAN_C, 
									cv2.THRESH_BINARY, 
									11, 2) 
		
		contours, _ = cv2.findContours(thresh.copy(), 
										cv2.RETR_EXTERNAL, 
										cv2.CHAIN_APPROX_NONE) 

		if contours: 
			areas = [cv2.contourArea(c) for c in contours] 
			
			# index of the largest contour in the area 
			# array 
			max_index = np.argmax(areas) 

			max_cnt = contours[max_index] 
			max_cntArea = areas[max_index] 
			x, y, w, h = cv2.boundingRect(max_cnt) 
			rect = cv2.minAreaRect(max_cnt) 
			if not self.ratioCheck(max_cntArea, plate.shape[1], 
												plate.shape[0]): 
				return plate, False, None
			
			return plate, True, [x, y, w, h] 
		
		else: 
			return plate, False, None



	def check_plate(self, input_img, contour): 
		
		min_rect = cv2.minAreaRect(contour) 
		
		if self.validateRatio(min_rect): 
			x, y, w, h = cv2.boundingRect(contour) 
			after_validation_img = input_img[y:y + h, x:x + w] 
			after_clean_plate_img, plateFound, coordinates = self.clean_plate( 
														after_validation_img) 
			
			if plateFound: 
				characters_on_plate = self.find_characters_on_plate( 
											after_clean_plate_img) 
				
				if (characters_on_plate is not None and len(characters_on_plate) == 8): 
					x1, y1, w1, h1 = coordinates 
					coordinates = x1 + x, y1 + y 
					after_check_plate_img = after_clean_plate_img 
					
					return after_check_plate_img, characters_on_plate, coordinates 
		
		return None, None, None



	def find_possible_plates(self, input_img): 
		
		""" 
		Finding all possible contours that can be plates 
		"""
		plates = [] 
		self.char_on_plate = [] 
		self.corresponding_area = [] 

		self.after_preprocess = self.preprocess(input_img) 
		possible_plate_contours = self.extract_contours(self.after_preprocess) 

		for cnts in possible_plate_contours: 
			plate, characters_on_plate, coordinates = self.check_plate(input_img, cnts) 
			
			if plate is not None: 
				plates.append(plate) 
				self.char_on_plate.append(characters_on_plate) 
				self.corresponding_area.append(coordinates) 

		if (len(plates) > 0): 
			return plates 
		
		else: 
			return None

	def find_characters_on_plate(self, plate): 

		charactersFound = segment_chars(plate, 400) 
		if charactersFound: 
			return charactersFound 

	# PLATE FEATURES 
	def ratioCheck(self, area, width, height): 
		
		min = self.min_area 
		max = self.max_area 

		ratioMin = 3
		ratioMax = 6

		ratio = float(width) / float(height) 
		
		if ratio < 1: 
			ratio = 1 / ratio 
		
		if (area < min or area > max) or (ratio < ratioMin or ratio > ratioMax): 
			return False
		
		return True

	def preRatioCheck(self, area, width, height): 
		
		min = self.min_area 
		max = self.max_area 

		ratioMin = 2.5
		ratioMax = 7

		ratio = float(width) / float(height) 
		
		if ratio < 1: 
			ratio = 1 / ratio 

		if (area < min or area > max) or (ratio < ratioMin or ratio > ratioMax): 
			return False
		
		return True

	def validateRatio(self, rect): 
		(x, y), (width, height), rect_angle = rect 

		if (width > height): 
			angle = -rect_angle 
		else: 
			angle = 90 + rect_angle 

		if angle > 15: 
			return False
		
		if (height == 0 or width == 0): 
			return False

		area = width * height 
		
		if not self.preRatioCheck(area, width, height): 
			return False
		else: 
			return True

# %%
class OCR: 
	
	def __init__(self, modelFile, labelFile): 
		
		self.model_file = modelFile 
		self.label_file = labelFile 
		self.label = self.load_label(self.label_file) 
		self.graph = self.load_graph(self.model_file) 
		self.sess = tf.compat.v1.Session(graph=self.graph, 
										config=tf.compat.v1.ConfigProto()) 

	def load_graph(self, modelFile): 
		
		graph = tf.Graph() 
		graph_def = tf.compat.v1.GraphDef() 
		
		with open(modelFile, "rb") as f: 
			graph_def.ParseFromString(f.read()) 
		
		with graph.as_default(): 
			tf.import_graph_def(graph_def) 
		
		return graph 

	def load_label(self, labelFile): 
		label = [] 
		proto_as_ascii_lines = tf.io.gfile.GFile(labelFile).readlines() 
		
		for l in proto_as_ascii_lines: 
			label.append(l.rstrip()) 
		
		return label 

	def convert_tensor(self, image, imageSizeOuput): 
		""" 
		takes an image and transform it in tensor 
		"""
		image = cv2.resize(image, 
						dsize =(imageSizeOuput, 
								imageSizeOuput), 
						interpolation = cv2.INTER_CUBIC) 
		
		np_image_data = np.asarray(image) 
		np_image_data = cv2.normalize(np_image_data.astype('float'), 
									None, -0.5, .5, 
									cv2.NORM_MINMAX) 
		
		np_final = np.expand_dims(np_image_data, axis = 0) 
		
		return np_final 

	def label_image(self, tensor): 

		input_name = "import/input"
		output_name = "import/final_result"

		input_operation = self.graph.get_operation_by_name(input_name) 
		output_operation = self.graph.get_operation_by_name(output_name) 

		results = self.sess.run(output_operation.outputs[0], 
								{input_operation.outputs[0]: tensor}) 
		results = np.squeeze(results) 
		labels = self.label 
		top = results.argsort()[-1:][::-1] 
		
		return labels[top[0]] 

	def label_image_list(self, listImages, imageSizeOuput): 
		plate = "" 
		
		for img in listImages: 
			
			if cv2.waitKey(25) & 0xFF == ord('q'): 
				break
			plate = plate + self.label_image(self.convert_tensor(img, imageSizeOuput)) 
		
		return plate, len(plate)

# %%
if __name__ == "__main__": 
	
	findPlate = PlateFinder(minPlateArea=4100, 
								maxPlateArea=15000) 
	model = OCR(modelFile="model/mobilenet.pb",
							labelFile="model/binary_128_0.50_labels_ver2.txt") 

	cap = cv2.VideoCapture('test.MOV') 
	
	while (cap.isOpened()): 
		ret, img = cap.read() 
		
		if ret == True: 
			cv2.imshow('original video', img) 
			
			if cv2.waitKey(25) & 0xFF == ord('q'): 
				break
			
			possible_plates = findPlate.find_possible_plates(img) 
			if possible_plates is not None: 
				
				for i, p in enumerate(possible_plates): 
					chars_on_plate = findPlate.char_on_plate[i] 
					recognized_plate, _ = model.label_image_list( 
							chars_on_plate, imageSizeOuput = 128) 

					print(recognized_plate) 
					cv2.imshow('plate', p) 
					
					if cv2.waitKey(25) & 0xFF == ord('q'): 
						break
		else: 
			break
			
	cap.release() 
	cv2.destroyAllWindows()
# Out:
# WARNING:tensorflow:From C:\Users\harsh\AppData\Local\Temp\ipykernel_12560\639155816.py:15: The name tf.GraphDef is deprecated. Please use tf.compat.v1.GraphDef instead.
#
# 29A39185
# 29A33185
# 29A33185

# %%
def calculate_accuracy(actual_plate, recognized_plates):
    """ Calculate the accuracy of recognized plates against the actual plate. """
    accuracies = []

    for recognized in recognized_plates:
        # Calculate match percentage character by character
        matches = sum(1 for ac, rc in zip(actual_plate, recognized) if ac == rc)
        max_length = max(len(actual_plate), len(recognized))
        accuracy = (matches / max_length) * 100
        accuracies.append(accuracy)
        print(f"Recognized: {recognized} | Accuracy: {accuracy:.2f}%")

    # Average accuracy across all recognized plates
    if accuracies:
        average_accuracy = sum(accuracies) / len(accuracies)
        print(f"Average Accuracy: {average_accuracy:.2f}%")
    else:
        print("No recognized plates to compare.")

# Example usage
actual_plate = input("Enter the actual number plate value: ")
recognized_plates = [
   "29A39185",
   "29A33185"
]

calculate_accuracy(actual_plate, recognized_plates)

# %%
def check_plate_accuracy(actual_plate, recognized_plates):
    """ Check if the actual plate is exactly present in the recognized plates. """
    # Print actual and recognized plates for clarity
    print("Actual Plate:", actual_plate)
    print("Recognized Plates:", recognized_plates)

    # Check if the actual plate is exactly in the recognized plates list
    if actual_plate in recognized_plates:
        print("Exact match found. Accuracy: 100%")
    else:
        print("No exact match found. Accuracy: 0%")

# Example usage
actual_plate = input("Enter the actual number plate value: ")
recognized_plates = [
    "29A39185",
    "29A33185",
]

check_plate_accuracy(actual_plate, recognized_plates)
# Out:
# Actual Plate: 29A39185
# Recognized Plates: ['29A39185', '29A33185']
# Exact match found. Accuracy: 100%

# %%
import tensorflow as tf

def load_graph(model_file):
    graph = tf.Graph()
    graph_def = tf.compat.v1.GraphDef()

    with open(model_file, "rb") as f:
        graph_def.ParseFromString(f.read())
    with graph.as_default():
        tf.import_graph_def(graph_def)

    return graph

if __name__ == "__main__":
    model_path = 'model/mobilenet.pb'  # Update this to the path of your model file
    graph = load_graph(model_path)
    for op in graph.get_operations():
        print(op.name)  # This prints all the operations in the model to the console
# Out:
# import/input
# import/MobilenetV1/Conv2d_0/weights
# import/MobilenetV1/Conv2d_0/weights/read
# import/MobilenetV1/MobilenetV1/Conv2d_0/convolution
# import/MobilenetV1/Conv2d_0/BatchNorm/beta
# import/MobilenetV1/Conv2d_0/BatchNorm/beta/read
# import/MobilenetV1/Conv2d_0/BatchNorm/gamma
# import/MobilenetV1/Conv2d_0/BatchNorm/gamma/read
# import/MobilenetV1/Conv2d_0/BatchNorm/moving_mean
# import/MobilenetV1/Conv2d_0/BatchNorm/moving_mean/read
# import/MobilenetV1/Conv2d_0/BatchNorm/moving_variance
# import/MobilenetV1/Conv2d_0/BatchNorm/moving_variance/read
# import/MobilenetV1/MobilenetV1/Conv2d_0/BatchNorm/batchnorm/add/y
# import/MobilenetV1/MobilenetV1/Conv2d_0/BatchNorm/batchnorm/add
# import/MobilenetV1/MobilenetV1/Conv2d_0/BatchNorm/batchnorm/Rsqrt
# import/MobilenetV1/MobilenetV1/Conv2d_0/BatchNorm/batchnorm/mul
# import/MobilenetV1/MobilenetV1/Conv2d_0/BatchNorm/batchnorm/mul_1
# import/MobilenetV1/MobilenetV1/Conv2d_0/BatchNorm/batchnorm/mul_2
# import/MobilenetV1/MobilenetV1/Conv2d_0/BatchNorm/batchnorm/sub
# import/MobilenetV1/MobilenetV1/Conv2d_0/BatchNorm/batchnorm/add_1
# import/MobilenetV1/MobilenetV1/Conv2d_0/Relu6
# import/MobilenetV1/Conv2d_1_depthwise/depthwise_weights
# import/MobilenetV1/Conv2d_1_depthwise/depthwise_weights/read
# import/MobilenetV1/MobilenetV1/Conv2d_1_depthwise/depthwise
# import/MobilenetV1/Conv2d_1_depthwise/BatchNorm/beta
# import/MobilenetV1/Conv2d_1_depthwise/BatchNorm/beta/read
# import/MobilenetV1/Conv2d_1_depthwise/BatchNorm/gamma
# import/MobilenetV1/Conv2d_1_depthwise/BatchNorm/gamma/read
# import/MobilenetV1/Conv2d_1_depthwise/BatchNorm/moving_mean
# import/MobilenetV1/Conv2d_1_depthwise/BatchNorm/moving_mean/read
# import/MobilenetV1/Conv2d_1_depthwise/BatchNorm/moving_variance
# import/MobilenetV1/Conv2d_1_depthwise/BatchNorm/moving_variance/read
# import/MobilenetV1/MobilenetV1/Conv2d_1_depthwise/BatchNorm/batchnorm/add/y
# import/MobilenetV1/MobilenetV1/Conv2d_1_depthwise/BatchNorm/batchnorm/add
# import/MobilenetV1/MobilenetV1/Conv2d_1_depthwise/BatchNorm/batchnorm/Rsqrt
# import/MobilenetV1/MobilenetV1/Conv2d_1_depthwise/BatchNorm/batchnorm/mul
# import/MobilenetV1/MobilenetV1/Conv2d_1_depthwise/BatchNorm/batchnorm/mul_1
# import/MobilenetV1/MobilenetV1/Conv2d_1_depthwise/BatchNorm/batchnorm/mul_2
# import/MobilenetV1/MobilenetV1/Conv2d_1_depthwise/BatchNorm/batchnorm/sub
# import/MobilenetV1/MobilenetV1/Conv2d_1_depthwise/BatchNorm/batchnorm/add_1
# import/MobilenetV1/MobilenetV1/Conv2d_1_depthwise/Relu6
# import/MobilenetV1/Conv2d_1_pointwise/weights
# import/MobilenetV1/Conv2d_1_pointwise/weights/read
# import/MobilenetV1/MobilenetV1/Conv2d_1_pointwise/convolution
# import/MobilenetV1/Conv2d_1_pointwise/BatchNorm/beta
# import/MobilenetV1/Conv2d_1_pointwise/BatchNorm/beta/read
# import/MobilenetV1/Conv2d_1_pointwise/BatchNorm/gamma
# import/MobilenetV1/Conv2d_1_pointwise/BatchNorm/gamma/read
# import/MobilenetV1/Conv2d_1_pointwise/BatchNorm/moving_mean
# import/MobilenetV1/Conv2d_1_pointwise/BatchNorm/moving_mean/read
# import/MobilenetV1/Conv2d_1_pointwise/BatchNorm/moving_variance
# import/MobilenetV1/Conv2d_1_pointwise/BatchNorm/moving_variance/read
# import/MobilenetV1/MobilenetV1/Conv2d_1_pointwise/BatchNorm/batchnorm/add/y
# import/MobilenetV1/MobilenetV1/Conv2d_1_pointwise/BatchNorm/batchnorm/add
# import/MobilenetV1/MobilenetV1/Conv2d_1_pointwise/BatchNorm/batchnorm/Rsqrt
# import/MobilenetV1/MobilenetV1/Conv2d_1_pointwise/BatchNorm/batchnorm/mul
# import/MobilenetV1/MobilenetV1/Conv2d_1_pointwise/BatchNorm/batchnorm/mul_1
# import/MobilenetV1/MobilenetV1/Conv2d_1_pointwise/BatchNorm/batchnorm/mul_2
# import/MobilenetV1/MobilenetV1/Conv2d_1_pointwise/BatchNorm/batchnorm/sub
# import/MobilenetV1/MobilenetV1/Conv2d_1_pointwise/BatchNorm/batchnorm/add_1
# import/MobilenetV1/MobilenetV1/Conv2d_1_pointwise/Relu6
# import/MobilenetV1/Conv2d_2_depthwise/depthwise_weights
# import/MobilenetV1/Conv2d_2_depthwise/depthwise_weights/read
# import/MobilenetV1/MobilenetV1/Conv2d_2_depthwise/depthwise
# import/MobilenetV1/Conv2d_2_depthwise/BatchNorm/beta
# import/MobilenetV1/Conv2d_2_depthwise/BatchNorm/beta/read
# import/MobilenetV1/Conv2d_2_depthwise/BatchNorm/gamma
# import/MobilenetV1/Conv2d_2_depthwise/BatchNorm/gamma/read
# import/MobilenetV1/Conv2d_2_depthwise/BatchNorm/moving_mean
# import/MobilenetV1/Conv2d_2_depthwise/BatchNorm/moving_mean/read
# import/MobilenetV1/Conv2d_2_depthwise/BatchNorm/moving_variance
# import/MobilenetV1/Conv2d_2_depthwise/BatchNorm/moving_variance/read
# import/MobilenetV1/MobilenetV1/Conv2d_2_depthwise/BatchNorm/batchnorm/add/y
# import/MobilenetV1/MobilenetV1/Conv2d_2_depthwise/BatchNorm/batchnorm/add
# import/MobilenetV1/MobilenetV1/Conv2d_2_depthwise/BatchNorm/batchnorm/Rsqrt
# import/MobilenetV1/MobilenetV1/Conv2d_2_depthwise/BatchNorm/batchnorm/mul
# import/MobilenetV1/MobilenetV1/Conv2d_2_depthwise/BatchNorm/batchnorm/mul_1
# import/MobilenetV1/MobilenetV1/Conv2d_2_depthwise/BatchNorm/batchnorm/mul_2
# import/MobilenetV1/MobilenetV1/Conv2d_2_depthwise/BatchNorm/batchnorm/sub
# import/MobilenetV1/MobilenetV1/Conv2d_2_depthwise/BatchNorm/batchnorm/add_1
# import/MobilenetV1/MobilenetV1/Conv2d_2_depthwise/Relu6
# import/MobilenetV1/Conv2d_2_pointwise/weights
# import/MobilenetV1/Conv2d_2_pointwise/weights/read
# import/MobilenetV1/MobilenetV1/Conv2d_2_pointwise/convolution
# import/MobilenetV1/Conv2d_2_pointwise/BatchNorm/beta
# import/MobilenetV1/Conv2d_2_pointwise/BatchNorm/beta/read
# import/MobilenetV1/Conv2d_2_pointwise/BatchNorm/gamma
# import/MobilenetV1/Conv2d_2_pointwise/BatchNorm/gamma/read
# import/MobilenetV1/Conv2d_2_pointwise/BatchNorm/moving_mean
# import/MobilenetV1/Conv2d_2_pointwise/BatchNorm/moving_mean/read
# import/MobilenetV1/Conv2d_2_pointwise/BatchNorm/moving_variance
# import/MobilenetV1/Conv2d_2_pointwise/BatchNorm/moving_variance/read
# import/MobilenetV1/MobilenetV1/Conv2d_2_pointwise/BatchNorm/batchnorm/add/y
# import/MobilenetV1/MobilenetV1/Conv2d_2_pointwise/BatchNorm/batchnorm/add
# import/MobilenetV1/MobilenetV1/Conv2d_2_pointwise/BatchNorm/batchnorm/Rsqrt
# import/MobilenetV1/MobilenetV1/Conv2d_2_pointwise/BatchNorm/batchnorm/mul
# import/MobilenetV1/MobilenetV1/Conv2d_2_pointwise/BatchNorm/batchnorm/mul_1
# import/MobilenetV1/MobilenetV1/Conv2d_2_pointwise/BatchNorm/batchnorm/mul_2
# import/MobilenetV1/MobilenetV1/Conv2d_2_pointwise/BatchNorm/batchnorm/sub
# import/MobilenetV1/MobilenetV1/Conv2d_2_pointwise/BatchNorm/batchnorm/add_1
# import/MobilenetV1/MobilenetV1/Conv2d_2_pointwise/Relu6
# import/MobilenetV1/Conv2d_3_depthwise/depthwise_weights
# import/MobilenetV1/Conv2d_3_depthwise/depthwise_weights/read
# import/MobilenetV1/MobilenetV1/Conv2d_3_depthwise/depthwise
# import/MobilenetV1/Conv2d_3_depthwise/BatchNorm/beta
# import/MobilenetV1/Conv2d_3_depthwise/BatchNorm/beta/read
# import/MobilenetV1/Conv2d_3_depthwise/BatchNorm/gamma
# import/MobilenetV1/Conv2d_3_depthwise/BatchNorm/gamma/read
# import/MobilenetV1/Conv2d_3_depthwise/BatchNorm/moving_mean
# import/MobilenetV1/Conv2d_3_depthwise/BatchNorm/moving_mean/read
# import/MobilenetV1/Conv2d_3_depthwise/BatchNorm/moving_variance
# import/MobilenetV1/Conv2d_3_depthwise/BatchNorm/moving_variance/read
# import/MobilenetV1/MobilenetV1/Conv2d_3_depthwise/BatchNorm/batchnorm/add/y
# import/MobilenetV1/MobilenetV1/Conv2d_3_depthwise/BatchNorm/batchnorm/add
# import/MobilenetV1/MobilenetV1/Conv2d_3_depthwise/BatchNorm/batchnorm/Rsqrt
# import/MobilenetV1/MobilenetV1/Conv2d_3_depthwise/BatchNorm/batchnorm/mul
# import/MobilenetV1/MobilenetV1/Conv2d_3_depthwise/BatchNorm/batchnorm/mul_1
# import/MobilenetV1/MobilenetV1/Conv2d_3_depthwise/BatchNorm/batchnorm/mul_2
# import/MobilenetV1/MobilenetV1/Conv2d_3_depthwise/BatchNorm/batchnorm/sub
# import/MobilenetV1/MobilenetV1/Conv2d_3_depthwise/BatchNorm/batchnorm/add_1
# import/MobilenetV1/MobilenetV1/Conv2d_3_depthwise/Relu6
# import/MobilenetV1/Conv2d_3_pointwise/weights
# import/MobilenetV1/Conv2d_3_pointwise/weights/read
# import/MobilenetV1/MobilenetV1/Conv2d_3_pointwise/convolution
# import/MobilenetV1/Conv2d_3_pointwise/BatchNorm/beta
# import/MobilenetV1/Conv2d_3_pointwise/BatchNorm/beta/read
# import/MobilenetV1/Conv2d_3_pointwise/BatchNorm/gamma
# import/MobilenetV1/Conv2d_3_pointwise/BatchNorm/gamma/read
# import/MobilenetV1/Conv2d_3_pointwise/BatchNorm/moving_mean
# import/MobilenetV1/Conv2d_3_pointwise/BatchNorm/moving_mean/read
# import/MobilenetV1/Conv2d_3_pointwise/BatchNorm/moving_variance
# import/MobilenetV1/Conv2d_3_pointwise/BatchNorm/moving_variance/read
# import/MobilenetV1/MobilenetV1/Conv2d_3_pointwise/BatchNorm/batchnorm/add/y
# import/MobilenetV1/MobilenetV1/Conv2d_3_pointwise/BatchNorm/batchnorm/add
# import/MobilenetV1/MobilenetV1/Conv2d_3_pointwise/BatchNorm/batchnorm/Rsqrt
# import/MobilenetV1/MobilenetV1/Conv2d_3_pointwise/BatchNorm/batchnorm/mul
# import/MobilenetV1/MobilenetV1/Conv2d_3_pointwise/BatchNorm/batchnorm/mul_1
# import/MobilenetV1/MobilenetV1/Conv2d_3_pointwise/BatchNorm/batchnorm/mul_2
# import/MobilenetV1/MobilenetV1/Conv2d_3_pointwise/BatchNorm/batchnorm/sub
# import/MobilenetV1/MobilenetV1/Conv2d_3_pointwise/BatchNorm/batchnorm/add_1
# import/MobilenetV1/MobilenetV1/Conv2d_3_pointwise/Relu6
# import/MobilenetV1/Conv2d_4_depthwise/depthwise_weights
# import/MobilenetV1/Conv2d_4_depthwise/depthwise_weights/read
# import/MobilenetV1/MobilenetV1/Conv2d_4_depthwise/depthwise
# import/MobilenetV1/Conv2d_4_depthwise/BatchNorm/beta
# import/MobilenetV1/Conv2d_4_depthwise/BatchNorm/beta/read
# import/MobilenetV1/Conv2d_4_depthwise/BatchNorm/gamma
# import/MobilenetV1/Conv2d_4_depthwise/BatchNorm/gamma/read
# import/MobilenetV1/Conv2d_4_depthwise/BatchNorm/moving_mean
# import/MobilenetV1/Conv2d_4_depthwise/BatchNorm/moving_mean/read
# import/MobilenetV1/Conv2d_4_depthwise/BatchNorm/moving_variance
# import/MobilenetV1/Conv2d_4_depthwise/BatchNorm/moving_variance/read
# import/MobilenetV1/MobilenetV1/Conv2d_4_depthwise/BatchNorm/batchnorm/add/y
# import/MobilenetV1/MobilenetV1/Conv2d_4_depthwise/BatchNorm/batchnorm/add
# import/MobilenetV1/MobilenetV1/Conv2d_4_depthwise/BatchNorm/batchnorm/Rsqrt
# import/MobilenetV1/MobilenetV1/Conv2d_4_depthwise/BatchNorm/batchnorm/mul
# import/MobilenetV1/MobilenetV1/Conv2d_4_depthwise/BatchNorm/batchnorm/mul_1
# import/MobilenetV1/MobilenetV1/Conv2d_4_depthwise/BatchNorm/batchnorm/mul_2
# import/MobilenetV1/MobilenetV1/Conv2d_4_depthwise/BatchNorm/batchnorm/sub
# import/MobilenetV1/MobilenetV1/Conv2d_4_depthwise/BatchNorm/batchnorm/add_1
# import/MobilenetV1/MobilenetV1/Conv2d_4_depthwise/Relu6
# import/MobilenetV1/Conv2d_4_pointwise/weights
# import/MobilenetV1/Conv2d_4_pointwise/weights/read
# import/MobilenetV1/MobilenetV1/Conv2d_4_pointwise/convolution
# import/MobilenetV1/Conv2d_4_pointwise/BatchNorm/beta
# import/MobilenetV1/Conv2d_4_pointwise/BatchNorm/beta/read
# import/MobilenetV1/Conv2d_4_pointwise/BatchNorm/gamma
# import/MobilenetV1/Conv2d_4_pointwise/BatchNorm/gamma/read
# import/MobilenetV1/Conv2d_4_pointwise/BatchNorm/moving_mean
# import/MobilenetV1/Conv2d_4_pointwise/BatchNorm/moving_mean/read
# import/MobilenetV1/Conv2d_4_pointwise/BatchNorm/moving_variance
# import/MobilenetV1/Conv2d_4_pointwise/BatchNorm/moving_variance/read
# import/MobilenetV1/MobilenetV1/Conv2d_4_pointwise/BatchNorm/batchnorm/add/y
# import/MobilenetV1/MobilenetV1/Conv2d_4_pointwise/BatchNorm/batchnorm/add
# import/MobilenetV1/MobilenetV1/Conv2d_4_pointwise/BatchNorm/batchnorm/Rsqrt
# import/MobilenetV1/MobilenetV1/Conv2d_4_pointwise/BatchNorm/batchnorm/mul
# import/MobilenetV1/MobilenetV1/Conv2d_4_pointwise/BatchNorm/batchnorm/mul_1
# import/MobilenetV1/MobilenetV1/Conv2d_4_pointwise/BatchNorm/batchnorm/mul_2
# import/MobilenetV1/MobilenetV1/Conv2d_4_pointwise/BatchNorm/batchnorm/sub
# import/MobilenetV1/MobilenetV1/Conv2d_4_pointwise/BatchNorm/batchnorm/add_1
# import/MobilenetV1/MobilenetV1/Conv2d_4_pointwise/Relu6
# import/MobilenetV1/Conv2d_5_depthwise/depthwise_weights
# import/MobilenetV1/Conv2d_5_depthwise/depthwise_weights/read
# import/MobilenetV1/MobilenetV1/Conv2d_5_depthwise/depthwise
# import/MobilenetV1/Conv2d_5_depthwise/BatchNorm/beta
# import/MobilenetV1/Conv2d_5_depthwise/BatchNorm/beta/read
# import/MobilenetV1/Conv2d_5_depthwise/BatchNorm/gamma
# import/MobilenetV1/Conv2d_5_depthwise/BatchNorm/gamma/read
# import/MobilenetV1/Conv2d_5_depthwise/BatchNorm/moving_mean
# import/MobilenetV1/Conv2d_5_depthwise/BatchNorm/moving_mean/read
# import/MobilenetV1/Conv2d_5_depthwise/BatchNorm/moving_variance
# import/MobilenetV1/Conv2d_5_depthwise/BatchNorm/moving_variance/read
# import/MobilenetV1/MobilenetV1/Conv2d_5_depthwise/BatchNorm/batchnorm/add/y
# import/MobilenetV1/MobilenetV1/Conv2d_5_depthwise/BatchNorm/batchnorm/add
# import/MobilenetV1/MobilenetV1/Conv2d_5_depthwise/BatchNorm/batchnorm/Rsqrt
# import/MobilenetV1/MobilenetV1/Conv2d_5_depthwise/BatchNorm/batchnorm/mul
# import/MobilenetV1/MobilenetV1/Conv2d_5_depthwise/BatchNorm/batchnorm/mul_1
# import/MobilenetV1/MobilenetV1/Conv2d_5_depthwise/BatchNorm/batchnorm/mul_2
# import/MobilenetV1/MobilenetV1/Conv2d_5_depthwise/BatchNorm/batchnorm/sub
# import/MobilenetV1/MobilenetV1/Conv2d_5_depthwise/BatchNorm/batchnorm/add_1
# import/MobilenetV1/MobilenetV1/Conv2d_5_depthwise/Relu6
# import/MobilenetV1/Conv2d_5_pointwise/weights
# import/MobilenetV1/Conv2d_5_pointwise/weights/read
# import/MobilenetV1/MobilenetV1/Conv2d_5_pointwise/convolution
# import/MobilenetV1/Conv2d_5_pointwise/BatchNorm/beta
# import/MobilenetV1/Conv2d_5_pointwise/BatchNorm/beta/read
# import/MobilenetV1/Conv2d_5_pointwise/BatchNorm/gamma
# import/MobilenetV1/Conv2d_5_pointwise/BatchNorm/gamma/read
# import/MobilenetV1/Conv2d_5_pointwise/BatchNorm/moving_mean
# import/MobilenetV1/Conv2d_5_pointwise/BatchNorm/moving_mean/read
# import/MobilenetV1/Conv2d_5_pointwise/BatchNorm/moving_variance
# import/MobilenetV1/Conv2d_5_pointwise/BatchNorm/moving_variance/read
# import/MobilenetV1/MobilenetV1/Conv2d_5_pointwise/BatchNorm/batchnorm/add/y
# import/MobilenetV1/MobilenetV1/Conv2d_5_pointwise/BatchNorm/batchnorm/add
# import/MobilenetV1/MobilenetV1/Conv2d_5_pointwise/BatchNorm/batchnorm/Rsqrt
# import/MobilenetV1/MobilenetV1/Conv2d_5_pointwise/BatchNorm/batchnorm/mul
# import/MobilenetV1/MobilenetV1/Conv2d_5_pointwise/BatchNorm/batchnorm/mul_1
# import/MobilenetV1/MobilenetV1/Conv2d_5_pointwise/BatchNorm/batchnorm/mul_2
# import/MobilenetV1/MobilenetV1/Conv2d_5_pointwise/BatchNorm/batchnorm/sub
# import/MobilenetV1/MobilenetV1/Conv2d_5_pointwise/BatchNorm/batchnorm/add_1
# import/MobilenetV1/MobilenetV1/Conv2d_5_pointwise/Relu6
# import/MobilenetV1/Conv2d_6_depthwise/depthwise_weights
# import/MobilenetV1/Conv2d_6_depthwise/depthwise_weights/read
# import/MobilenetV1/MobilenetV1/Conv2d_6_depthwise/depthwise
# import/MobilenetV1/Conv2d_6_depthwise/BatchNorm/beta
# import/MobilenetV1/Conv2d_6_depthwise/BatchNorm/beta/read
# import/MobilenetV1/Conv2d_6_depthwise/BatchNorm/gamma
# import/MobilenetV1/Conv2d_6_depthwise/BatchNorm/gamma/read
# import/MobilenetV1/Conv2d_6_depthwise/BatchNorm/moving_mean
# import/MobilenetV1/Conv2d_6_depthwise/BatchNorm/moving_mean/read
# import/MobilenetV1/Conv2d_6_depthwise/BatchNorm/moving_variance
# import/MobilenetV1/Conv2d_6_depthwise/BatchNorm/moving_variance/read
# import/MobilenetV1/MobilenetV1/Conv2d_6_depthwise/BatchNorm/batchnorm/add/y
# import/MobilenetV1/MobilenetV1/Conv2d_6_depthwise/BatchNorm/batchnorm/add
# import/MobilenetV1/MobilenetV1/Conv2d_6_depthwise/BatchNorm/batchnorm/Rsqrt
# import/MobilenetV1/MobilenetV1/Conv2d_6_depthwise/BatchNorm/batchnorm/mul
# import/MobilenetV1/MobilenetV1/Conv2d_6_depthwise/BatchNorm/batchnorm/mul_1
# import/MobilenetV1/MobilenetV1/Conv2d_6_depthwise/BatchNorm/batchnorm/mul_2
# import/MobilenetV1/MobilenetV1/Conv2d_6_depthwise/BatchNorm/batchnorm/sub
# import/MobilenetV1/MobilenetV1/Conv2d_6_depthwise/BatchNorm/batchnorm/add_1
# import/MobilenetV1/MobilenetV1/Conv2d_6_depthwise/Relu6
# import/MobilenetV1/Conv2d_6_pointwise/weights
# import/MobilenetV1/Conv2d_6_pointwise/weights/read
# import/MobilenetV1/MobilenetV1/Conv2d_6_pointwise/convolution
# import/MobilenetV1/Conv2d_6_pointwise/BatchNorm/beta
# import/MobilenetV1/Conv2d_6_pointwise/BatchNorm/beta/read
# import/MobilenetV1/Conv2d_6_pointwise/BatchNorm/gamma
# import/MobilenetV1/Conv2d_6_pointwise/BatchNorm/gamma/read
# import/MobilenetV1/Conv2d_6_pointwise/BatchNorm/moving_mean
# import/MobilenetV1/Conv2d_6_pointwise/BatchNorm/moving_mean/read
# import/MobilenetV1/Conv2d_6_pointwise/BatchNorm/moving_variance
# import/MobilenetV1/Conv2d_6_pointwise/BatchNorm/moving_variance/read
# import/MobilenetV1/MobilenetV1/Conv2d_6_pointwise/BatchNorm/batchnorm/add/y
# import/MobilenetV1/MobilenetV1/Conv2d_6_pointwise/BatchNorm/batchnorm/add
# import/MobilenetV1/MobilenetV1/Conv2d_6_pointwise/BatchNorm/batchnorm/Rsqrt
# import/MobilenetV1/MobilenetV1/Conv2d_6_pointwise/BatchNorm/batchnorm/mul
# import/MobilenetV1/MobilenetV1/Conv2d_6_pointwise/BatchNorm/batchnorm/mul_1
# import/MobilenetV1/MobilenetV1/Conv2d_6_pointwise/BatchNorm/batchnorm/mul_2
# import/MobilenetV1/MobilenetV1/Conv2d_6_pointwise/BatchNorm/batchnorm/sub
# import/MobilenetV1/MobilenetV1/Conv2d_6_pointwise/BatchNorm/batchnorm/add_1
# import/MobilenetV1/MobilenetV1/Conv2d_6_pointwise/Relu6
# import/MobilenetV1/Conv2d_7_depthwise/depthwise_weights
# import/MobilenetV1/Conv2d_7_depthwise/depthwise_weights/read
# import/MobilenetV1/MobilenetV1/Conv2d_7_depthwise/depthwise
# import/MobilenetV1/Conv2d_7_depthwise/BatchNorm/beta
# import/MobilenetV1/Conv2d_7_depthwise/BatchNorm/beta/read
# import/MobilenetV1/Conv2d_7_depthwise/BatchNorm/gamma
# import/MobilenetV1/Conv2d_7_depthwise/BatchNorm/gamma/read
# import/MobilenetV1/Conv2d_7_depthwise/BatchNorm/moving_mean
# import/MobilenetV1/Conv2d_7_depthwise/BatchNorm/moving_mean/read
# import/MobilenetV1/Conv2d_7_depthwise/BatchNorm/moving_variance
# import/MobilenetV1/Conv2d_7_depthwise/BatchNorm/moving_variance/read
# import/MobilenetV1/MobilenetV1/Conv2d_7_depthwise/BatchNorm/batchnorm/add/y
# import/MobilenetV1/MobilenetV1/Conv2d_7_depthwise/BatchNorm/batchnorm/add
# import/MobilenetV1/MobilenetV1/Conv2d_7_depthwise/BatchNorm/batchnorm/Rsqrt
# import/MobilenetV1/MobilenetV1/Conv2d_7_depthwise/BatchNorm/batchnorm/mul
# import/MobilenetV1/MobilenetV1/Conv2d_7_depthwise/BatchNorm/batchnorm/mul_1
# import/MobilenetV1/MobilenetV1/Conv2d_7_depthwise/BatchNorm/batchnorm/mul_2
# import/MobilenetV1/MobilenetV1/Conv2d_7_depthwise/BatchNorm/batchnorm/sub
# import/MobilenetV1/MobilenetV1/Conv2d_7_depthwise/BatchNorm/batchnorm/add_1
# import/MobilenetV1/MobilenetV1/Conv2d_7_depthwise/Relu6
# import/MobilenetV1/Conv2d_7_pointwise/weights
# import/MobilenetV1/Conv2d_7_pointwise/weights/read
# import/MobilenetV1/MobilenetV1/Conv2d_7_pointwise/convolution
# import/MobilenetV1/Conv2d_7_pointwise/BatchNorm/beta
# import/MobilenetV1/Conv2d_7_pointwise/BatchNorm/beta/read
# import/MobilenetV1/Conv2d_7_pointwise/BatchNorm/gamma
# import/MobilenetV1/Conv2d_7_pointwise/BatchNorm/gamma/read
# import/MobilenetV1/Conv2d_7_pointwise/BatchNorm/moving_mean
# import/MobilenetV1/Conv2d_7_pointwise/BatchNorm/moving_mean/read
# import/MobilenetV1/Conv2d_7_pointwise/BatchNorm/moving_variance
# import/MobilenetV1/Conv2d_7_pointwise/BatchNorm/moving_variance/read
# import/MobilenetV1/MobilenetV1/Conv2d_7_pointwise/BatchNorm/batchnorm/add/y
# import/MobilenetV1/MobilenetV1/Conv2d_7_pointwise/BatchNorm/batchnorm/add
# import/MobilenetV1/MobilenetV1/Conv2d_7_pointwise/BatchNorm/batchnorm/Rsqrt
# import/MobilenetV1/MobilenetV1/Conv2d_7_pointwise/BatchNorm/batchnorm/mul
# import/MobilenetV1/MobilenetV1/Conv2d_7_pointwise/BatchNorm/batchnorm/mul_1
# import/MobilenetV1/MobilenetV1/Conv2d_7_pointwise/BatchNorm/batchnorm/mul_2
# import/MobilenetV1/MobilenetV1/Conv2d_7_pointwise/BatchNorm/batchnorm/sub
# import/MobilenetV1/MobilenetV1/Conv2d_7_pointwise/BatchNorm/batchnorm/add_1
# import/MobilenetV1/MobilenetV1/Conv2d_7_pointwise/Relu6
# import/MobilenetV1/Conv2d_8_depthwise/depthwise_weights
# import/MobilenetV1/Conv2d_8_depthwise/depthwise_weights/read
# import/MobilenetV1/MobilenetV1/Conv2d_8_depthwise/depthwise
# import/MobilenetV1/Conv2d_8_depthwise/BatchNorm/beta
# import/MobilenetV1/Conv2d_8_depthwise/BatchNorm/beta/read
# import/MobilenetV1/Conv2d_8_depthwise/BatchNorm/gamma
# import/MobilenetV1/Conv2d_8_depthwise/BatchNorm/gamma/read
# import/MobilenetV1/Conv2d_8_depthwise/BatchNorm/moving_mean
# import/MobilenetV1/Conv2d_8_depthwise/BatchNorm/moving_mean/read
# import/MobilenetV1/Conv2d_8_depthwise/BatchNorm/moving_variance
# import/MobilenetV1/Conv2d_8_depthwise/BatchNorm/moving_variance/read
# import/MobilenetV1/MobilenetV1/Conv2d_8_depthwise/BatchNorm/batchnorm/add/y
# import/MobilenetV1/MobilenetV1/Conv2d_8_depthwise/BatchNorm/batchnorm/add
# import/MobilenetV1/MobilenetV1/Conv2d_8_depthwise/BatchNorm/batchnorm/Rsqrt
# import/MobilenetV1/MobilenetV1/Conv2d_8_depthwise/BatchNorm/batchnorm/mul
# import/MobilenetV1/MobilenetV1/Conv2d_8_depthwise/BatchNorm/batchnorm/mul_1
# import/MobilenetV1/MobilenetV1/Conv2d_8_depthwise/BatchNorm/batchnorm/mul_2
# import/MobilenetV1/MobilenetV1/Conv2d_8_depthwise/BatchNorm/batchnorm/sub
# import/MobilenetV1/MobilenetV1/Conv2d_8_depthwise/BatchNorm/batchnorm/add_1
# import/MobilenetV1/MobilenetV1/Conv2d_8_depthwise/Relu6
# import/MobilenetV1/Conv2d_8_pointwise/weights
# import/MobilenetV1/Conv2d_8_pointwise/weights/read
# import/MobilenetV1/MobilenetV1/Conv2d_8_pointwise/convolution
# import/MobilenetV1/Conv2d_8_pointwise/BatchNorm/beta
# import/MobilenetV1/Conv2d_8_pointwise/BatchNorm/beta/read
# import/MobilenetV1/Conv2d_8_pointwise/BatchNorm/gamma
# import/MobilenetV1/Conv2d_8_pointwise/BatchNorm/gamma/read
# import/MobilenetV1/Conv2d_8_pointwise/BatchNorm/moving_mean
# import/MobilenetV1/Conv2d_8_pointwise/BatchNorm/moving_mean/read
# import/MobilenetV1/Conv2d_8_pointwise/BatchNorm/moving_variance
# import/MobilenetV1/Conv2d_8_pointwise/BatchNorm/moving_variance/read
# import/MobilenetV1/MobilenetV1/Conv2d_8_pointwise/BatchNorm/batchnorm/add/y
# import/MobilenetV1/MobilenetV1/Conv2d_8_pointwise/BatchNorm/batchnorm/add
# import/MobilenetV1/MobilenetV1/Conv2d_8_pointwise/BatchNorm/batchnorm/Rsqrt
# import/MobilenetV1/MobilenetV1/Conv2d_8_pointwise/BatchNorm/batchnorm/mul
# import/MobilenetV1/MobilenetV1/Conv2d_8_pointwise/BatchNorm/batchnorm/mul_1
# import/MobilenetV1/MobilenetV1/Conv2d_8_pointwise/BatchNorm/batchnorm/mul_2
# import/MobilenetV1/MobilenetV1/Conv2d_8_pointwise/BatchNorm/batchnorm/sub
# import/MobilenetV1/MobilenetV1/Conv2d_8_pointwise/BatchNorm/batchnorm/add_1
# import/MobilenetV1/MobilenetV1/Conv2d_8_pointwise/Relu6
# import/MobilenetV1/Conv2d_9_depthwise/depthwise_weights
# import/MobilenetV1/Conv2d_9_depthwise/depthwise_weights/read
# import/MobilenetV1/MobilenetV1/Conv2d_9_depthwise/depthwise
# import/MobilenetV1/Conv2d_9_depthwise/BatchNorm/beta
# import/MobilenetV1/Conv2d_9_depthwise/BatchNorm/beta/read
# import/MobilenetV1/Conv2d_9_depthwise/BatchNorm/gamma
# import/MobilenetV1/Conv2d_9_depthwise/BatchNorm/gamma/read
# import/MobilenetV1/Conv2d_9_depthwise/BatchNorm/moving_mean
# import/MobilenetV1/Conv2d_9_depthwise/BatchNorm/moving_mean/read
# import/MobilenetV1/Conv2d_9_depthwise/BatchNorm/moving_variance
# import/MobilenetV1/Conv2d_9_depthwise/BatchNorm/moving_variance/read
# import/MobilenetV1/MobilenetV1/Conv2d_9_depthwise/BatchNorm/batchnorm/add/y
# import/MobilenetV1/MobilenetV1/Conv2d_9_depthwise/BatchNorm/batchnorm/add
# import/MobilenetV1/MobilenetV1/Conv2d_9_depthwise/BatchNorm/batchnorm/Rsqrt
# import/MobilenetV1/MobilenetV1/Conv2d_9_depthwise/BatchNorm/batchnorm/mul
# import/MobilenetV1/MobilenetV1/Conv2d_9_depthwise/BatchNorm/batchnorm/mul_1
# import/MobilenetV1/MobilenetV1/Conv2d_9_depthwise/BatchNorm/batchnorm/mul_2
# import/MobilenetV1/MobilenetV1/Conv2d_9_depthwise/BatchNorm/batchnorm/sub
# import/MobilenetV1/MobilenetV1/Conv2d_9_depthwise/BatchNorm/batchnorm/add_1
# import/MobilenetV1/MobilenetV1/Conv2d_9_depthwise/Relu6
# import/MobilenetV1/Conv2d_9_pointwise/weights
# import/MobilenetV1/Conv2d_9_pointwise/weights/read
# import/MobilenetV1/MobilenetV1/Conv2d_9_pointwise/convolution
# import/MobilenetV1/Conv2d_9_pointwise/BatchNorm/beta
# import/MobilenetV1/Conv2d_9_pointwise/BatchNorm/beta/read
# import/MobilenetV1/Conv2d_9_pointwise/BatchNorm/gamma
# import/MobilenetV1/Conv2d_9_pointwise/BatchNorm/gamma/read
# import/MobilenetV1/Conv2d_9_pointwise/BatchNorm/moving_mean
# import/MobilenetV1/Conv2d_9_pointwise/BatchNorm/moving_mean/read
# import/MobilenetV1/Conv2d_9_pointwise/BatchNorm/moving_variance
# import/MobilenetV1/Conv2d_9_pointwise/BatchNorm/moving_variance/read
# import/MobilenetV1/MobilenetV1/Conv2d_9_pointwise/BatchNorm/batchnorm/add/y
# import/MobilenetV1/MobilenetV1/Conv2d_9_pointwise/BatchNorm/batchnorm/add
# import/MobilenetV1/MobilenetV1/Conv2d_9_pointwise/BatchNorm/batchnorm/Rsqrt
# import/MobilenetV1/MobilenetV1/Conv2d_9_pointwise/BatchNorm/batchnorm/mul
# import/MobilenetV1/MobilenetV1/Conv2d_9_pointwise/BatchNorm/batchnorm/mul_1
# import/MobilenetV1/MobilenetV1/Conv2d_9_pointwise/BatchNorm/batchnorm/mul_2
# import/MobilenetV1/MobilenetV1/Conv2d_9_pointwise/BatchNorm/batchnorm/sub
# import/MobilenetV1/MobilenetV1/Conv2d_9_pointwise/BatchNorm/batchnorm/add_1
# import/MobilenetV1/MobilenetV1/Conv2d_9_pointwise/Relu6
# import/MobilenetV1/Conv2d_10_depthwise/depthwise_weights
# import/MobilenetV1/Conv2d_10_depthwise/depthwise_weights/read
# import/MobilenetV1/MobilenetV1/Conv2d_10_depthwise/depthwise
# import/MobilenetV1/Conv2d_10_depthwise/BatchNorm/beta
# import/MobilenetV1/Conv2d_10_depthwise/BatchNorm/beta/read
# import/MobilenetV1/Conv2d_10_depthwise/BatchNorm/gamma
# import/MobilenetV1/Conv2d_10_depthwise/BatchNorm/gamma/read
# import/MobilenetV1/Conv2d_10_depthwise/BatchNorm/moving_mean
# import/MobilenetV1/Conv2d_10_depthwise/BatchNorm/moving_mean/read
# import/MobilenetV1/Conv2d_10_depthwise/BatchNorm/moving_variance
# import/MobilenetV1/Conv2d_10_depthwise/BatchNorm/moving_variance/read
# import/MobilenetV1/MobilenetV1/Conv2d_10_depthwise/BatchNorm/batchnorm/add/y
# import/MobilenetV1/MobilenetV1/Conv2d_10_depthwise/BatchNorm/batchnorm/add
# import/MobilenetV1/MobilenetV1/Conv2d_10_depthwise/BatchNorm/batchnorm/Rsqrt
# import/MobilenetV1/MobilenetV1/Conv2d_10_depthwise/BatchNorm/batchnorm/mul
# import/MobilenetV1/MobilenetV1/Conv2d_10_depthwise/BatchNorm/batchnorm/mul_1
# import/MobilenetV1/MobilenetV1/Conv2d_10_depthwise/BatchNorm/batchnorm/mul_2
# import/MobilenetV1/MobilenetV1/Conv2d_10_depthwise/BatchNorm/batchnorm/sub
# import/MobilenetV1/MobilenetV1/Conv2d_10_depthwise/BatchNorm/batchnorm/add_1
# import/MobilenetV1/MobilenetV1/Conv2d_10_depthwise/Relu6
# import/MobilenetV1/Conv2d_10_pointwise/weights
# import/MobilenetV1/Conv2d_10_pointwise/weights/read
# import/MobilenetV1/MobilenetV1/Conv2d_10_pointwise/convolution
# import/MobilenetV1/Conv2d_10_pointwise/BatchNorm/beta
# import/MobilenetV1/Conv2d_10_pointwise/BatchNorm/beta/read
# import/MobilenetV1/Conv2d_10_pointwise/BatchNorm/gamma
# import/MobilenetV1/Conv2d_10_pointwise/BatchNorm/gamma/read
# import/MobilenetV1/Conv2d_10_pointwise/BatchNorm/moving_mean
# import/MobilenetV1/Conv2d_10_pointwise/BatchNorm/moving_mean/read
# import/MobilenetV1/Conv2d_10_pointwise/BatchNorm/moving_variance
# import/MobilenetV1/Conv2d_10_pointwise/BatchNorm/moving_variance/read
# import/MobilenetV1/MobilenetV1/Conv2d_10_pointwise/BatchNorm/batchnorm/add/y
# import/MobilenetV1/MobilenetV1/Conv2d_10_pointwise/BatchNorm/batchnorm/add
# import/MobilenetV1/MobilenetV1/Conv2d_10_pointwise/BatchNorm/batchnorm/Rsqrt
# import/MobilenetV1/MobilenetV1/Conv2d_10_pointwise/BatchNorm/batchnorm/mul
# import/MobilenetV1/MobilenetV1/Conv2d_10_pointwise/BatchNorm/batchnorm/mul_1
# import/MobilenetV1/MobilenetV1/Conv2d_10_pointwise/BatchNorm/batchnorm/mul_2
# import/MobilenetV1/MobilenetV1/Conv2d_10_pointwise/BatchNorm/batchnorm/sub
# import/MobilenetV1/MobilenetV1/Conv2d_10_pointwise/BatchNorm/batchnorm/add_1
# import/MobilenetV1/MobilenetV1/Conv2d_10_pointwise/Relu6
# import/MobilenetV1/Conv2d_11_depthwise/depthwise_weights
# import/MobilenetV1/Conv2d_11_depthwise/depthwise_weights/read
# import/MobilenetV1/MobilenetV1/Conv2d_11_depthwise/depthwise
# import/MobilenetV1/Conv2d_11_depthwise/BatchNorm/beta
# import/MobilenetV1/Conv2d_11_depthwise/BatchNorm/beta/read
# import/MobilenetV1/Conv2d_11_depthwise/BatchNorm/gamma
# import/MobilenetV1/Conv2d_11_depthwise/BatchNorm/gamma/read
# import/MobilenetV1/Conv2d_11_depthwise/BatchNorm/moving_mean
# import/MobilenetV1/Conv2d_11_depthwise/BatchNorm/moving_mean/read
# import/MobilenetV1/Conv2d_11_depthwise/BatchNorm/moving_variance
# import/MobilenetV1/Conv2d_11_depthwise/BatchNorm/moving_variance/read
# import/MobilenetV1/MobilenetV1/Conv2d_11_depthwise/BatchNorm/batchnorm/add/y
# import/MobilenetV1/MobilenetV1/Conv2d_11_depthwise/BatchNorm/batchnorm/add
# import/MobilenetV1/MobilenetV1/Conv2d_11_depthwise/BatchNorm/batchnorm/Rsqrt
# import/MobilenetV1/MobilenetV1/Conv2d_11_depthwise/BatchNorm/batchnorm/mul
# import/MobilenetV1/MobilenetV1/Conv2d_11_depthwise/BatchNorm/batchnorm/mul_1
# import/MobilenetV1/MobilenetV1/Conv2d_11_depthwise/BatchNorm/batchnorm/mul_2
# import/MobilenetV1/MobilenetV1/Conv2d_11_depthwise/BatchNorm/batchnorm/sub
# import/MobilenetV1/MobilenetV1/Conv2d_11_depthwise/BatchNorm/batchnorm/add_1
# import/MobilenetV1/MobilenetV1/Conv2d_11_depthwise/Relu6
# import/MobilenetV1/Conv2d_11_pointwise/weights
# import/MobilenetV1/Conv2d_11_pointwise/weights/read
# import/MobilenetV1/MobilenetV1/Conv2d_11_pointwise/convolution
# import/MobilenetV1/Conv2d_11_pointwise/BatchNorm/beta
# import/MobilenetV1/Conv2d_11_pointwise/BatchNorm/beta/read
# import/MobilenetV1/Conv2d_11_pointwise/BatchNorm/gamma
# import/MobilenetV1/Conv2d_11_pointwise/BatchNorm/gamma/read
# import/MobilenetV1/Conv2d_11_pointwise/BatchNorm/moving_mean
# import/MobilenetV1/Conv2d_11_pointwise/BatchNorm/moving_mean/read
# import/MobilenetV1/Conv2d_11_pointwise/BatchNorm/moving_variance
# import/MobilenetV1/Conv2d_11_pointwise/BatchNorm/moving_variance/read
# import/MobilenetV1/MobilenetV1/Conv2d_11_pointwise/BatchNorm/batchnorm/add/y
# import/MobilenetV1/MobilenetV1/Conv2d_11_pointwise/BatchNorm/batchnorm/add
# import/MobilenetV1/MobilenetV1/Conv2d_11_pointwise/BatchNorm/batchnorm/Rsqrt
# import/MobilenetV1/MobilenetV1/Conv2d_11_pointwise/BatchNorm/batchnorm/mul
# import/MobilenetV1/MobilenetV1/Conv2d_11_pointwise/BatchNorm/batchnorm/mul_1
# import/MobilenetV1/MobilenetV1/Conv2d_11_pointwise/BatchNorm/batchnorm/mul_2
# import/MobilenetV1/MobilenetV1/Conv2d_11_pointwise/BatchNorm/batchnorm/sub
# import/MobilenetV1/MobilenetV1/Conv2d_11_pointwise/BatchNorm/batchnorm/add_1
# import/MobilenetV1/MobilenetV1/Conv2d_11_pointwise/Relu6
# import/MobilenetV1/Conv2d_12_depthwise/depthwise_weights
# import/MobilenetV1/Conv2d_12_depthwise/depthwise_weights/read
# import/MobilenetV1/MobilenetV1/Conv2d_12_depthwise/depthwise
# import/MobilenetV1/Conv2d_12_depthwise/BatchNorm/beta
# import/MobilenetV1/Conv2d_12_depthwise/BatchNorm/beta/read
# import/MobilenetV1/Conv2d_12_depthwise/BatchNorm/gamma
# import/MobilenetV1/Conv2d_12_depthwise/BatchNorm/gamma/read
# import/MobilenetV1/Conv2d_12_depthwise/BatchNorm/moving_mean
# import/MobilenetV1/Conv2d_12_depthwise/BatchNorm/moving_mean/read
# import/MobilenetV1/Conv2d_12_depthwise/BatchNorm/moving_variance
# import/MobilenetV1/Conv2d_12_depthwise/BatchNorm/moving_variance/read
# import/MobilenetV1/MobilenetV1/Conv2d_12_depthwise/BatchNorm/batchnorm/add/y
# import/MobilenetV1/MobilenetV1/Conv2d_12_depthwise/BatchNorm/batchnorm/add
# import/MobilenetV1/MobilenetV1/Conv2d_12_depthwise/BatchNorm/batchnorm/Rsqrt
# import/MobilenetV1/MobilenetV1/Conv2d_12_depthwise/BatchNorm/batchnorm/mul
# import/MobilenetV1/MobilenetV1/Conv2d_12_depthwise/BatchNorm/batchnorm/mul_1
# import/MobilenetV1/MobilenetV1/Conv2d_12_depthwise/BatchNorm/batchnorm/mul_2
# import/MobilenetV1/MobilenetV1/Conv2d_12_depthwise/BatchNorm/batchnorm/sub
# import/MobilenetV1/MobilenetV1/Conv2d_12_depthwise/BatchNorm/batchnorm/add_1
# import/MobilenetV1/MobilenetV1/Conv2d_12_depthwise/Relu6
# import/MobilenetV1/Conv2d_12_pointwise/weights
# import/MobilenetV1/Conv2d_12_pointwise/weights/read
# import/MobilenetV1/MobilenetV1/Conv2d_12_pointwise/convolution
# import/MobilenetV1/Conv2d_12_pointwise/BatchNorm/beta
# import/MobilenetV1/Conv2d_12_pointwise/BatchNorm/beta/read
# import/MobilenetV1/Conv2d_12_pointwise/BatchNorm/gamma
# import/MobilenetV1/Conv2d_12_pointwise/BatchNorm/gamma/read
# import/MobilenetV1/Conv2d_12_pointwise/BatchNorm/moving_mean
# import/MobilenetV1/Conv2d_12_pointwise/BatchNorm/moving_mean/read
# import/MobilenetV1/Conv2d_12_pointwise/BatchNorm/moving_variance
# import/MobilenetV1/Conv2d_12_pointwise/BatchNorm/moving_variance/read
# import/MobilenetV1/MobilenetV1/Conv2d_12_pointwise/BatchNorm/batchnorm/add/y
# import/MobilenetV1/MobilenetV1/Conv2d_12_pointwise/BatchNorm/batchnorm/add
# import/MobilenetV1/MobilenetV1/Conv2d_12_pointwise/BatchNorm/batchnorm/Rsqrt
# import/MobilenetV1/MobilenetV1/Conv2d_12_pointwise/BatchNorm/batchnorm/mul
# import/MobilenetV1/MobilenetV1/Conv2d_12_pointwise/BatchNorm/batchnorm/mul_1
# import/MobilenetV1/MobilenetV1/Conv2d_12_pointwise/BatchNorm/batchnorm/mul_2
# import/MobilenetV1/MobilenetV1/Conv2d_12_pointwise/BatchNorm/batchnorm/sub
# import/MobilenetV1/MobilenetV1/Conv2d_12_pointwise/BatchNorm/batchnorm/add_1
# import/MobilenetV1/MobilenetV1/Conv2d_12_pointwise/Relu6
# import/MobilenetV1/Conv2d_13_depthwise/depthwise_weights
# import/MobilenetV1/Conv2d_13_depthwise/depthwise_weights/read
# import/MobilenetV1/MobilenetV1/Conv2d_13_depthwise/depthwise
# import/MobilenetV1/Conv2d_13_depthwise/BatchNorm/beta
# import/MobilenetV1/Conv2d_13_depthwise/BatchNorm/beta/read
# import/MobilenetV1/Conv2d_13_depthwise/BatchNorm/gamma
# import/MobilenetV1/Conv2d_13_depthwise/BatchNorm/gamma/read
# import/MobilenetV1/Conv2d_13_depthwise/BatchNorm/moving_mean
# import/MobilenetV1/Conv2d_13_depthwise/BatchNorm/moving_mean/read
# import/MobilenetV1/Conv2d_13_depthwise/BatchNorm/moving_variance
# import/MobilenetV1/Conv2d_13_depthwise/BatchNorm/moving_variance/read
# import/MobilenetV1/MobilenetV1/Conv2d_13_depthwise/BatchNorm/batchnorm/add/y
# import/MobilenetV1/MobilenetV1/Conv2d_13_depthwise/BatchNorm/batchnorm/add
# import/MobilenetV1/MobilenetV1/Conv2d_13_depthwise/BatchNorm/batchnorm/Rsqrt
# import/MobilenetV1/MobilenetV1/Conv2d_13_depthwise/BatchNorm/batchnorm/mul
# import/MobilenetV1/MobilenetV1/Conv2d_13_depthwise/BatchNorm/batchnorm/mul_1
# import/MobilenetV1/MobilenetV1/Conv2d_13_depthwise/BatchNorm/batchnorm/mul_2
# import/MobilenetV1/MobilenetV1/Conv2d_13_depthwise/BatchNorm/batchnorm/sub
# import/MobilenetV1/MobilenetV1/Conv2d_13_depthwise/BatchNorm/batchnorm/add_1
# import/MobilenetV1/MobilenetV1/Conv2d_13_depthwise/Relu6
# import/MobilenetV1/Conv2d_13_pointwise/weights
# import/MobilenetV1/Conv2d_13_pointwise/weights/read
# import/MobilenetV1/MobilenetV1/Conv2d_13_pointwise/convolution
# import/MobilenetV1/Conv2d_13_pointwise/BatchNorm/beta
# import/MobilenetV1/Conv2d_13_pointwise/BatchNorm/beta/read
# import/MobilenetV1/Conv2d_13_pointwise/BatchNorm/gamma
# import/MobilenetV1/Conv2d_13_pointwise/BatchNorm/gamma/read
# import/MobilenetV1/Conv2d_13_pointwise/BatchNorm/moving_mean
# import/MobilenetV1/Conv2d_13_pointwise/BatchNorm/moving_mean/read
# import/MobilenetV1/Conv2d_13_pointwise/BatchNorm/moving_variance
# import/MobilenetV1/Conv2d_13_pointwise/BatchNorm/moving_variance/read
# import/MobilenetV1/MobilenetV1/Conv2d_13_pointwise/BatchNorm/batchnorm/add/y
# import/MobilenetV1/MobilenetV1/Conv2d_13_pointwise/BatchNorm/batchnorm/add
# import/MobilenetV1/MobilenetV1/Conv2d_13_pointwise/BatchNorm/batchnorm/Rsqrt
# import/MobilenetV1/MobilenetV1/Conv2d_13_pointwise/BatchNorm/batchnorm/mul
# import/MobilenetV1/MobilenetV1/Conv2d_13_pointwise/BatchNorm/batchnorm/mul_1
# import/MobilenetV1/MobilenetV1/Conv2d_13_pointwise/BatchNorm/batchnorm/mul_2
# import/MobilenetV1/MobilenetV1/Conv2d_13_pointwise/BatchNorm/batchnorm/sub
# import/MobilenetV1/MobilenetV1/Conv2d_13_pointwise/BatchNorm/batchnorm/add_1
# import/MobilenetV1/MobilenetV1/Conv2d_13_pointwise/Relu6
# import/MobilenetV1/Logits/AvgPool_1a/AvgPool
# import/MobilenetV1/Logits/Dropout_1b/Identity
# import/MobilenetV1/Logits/Conv2d_1c_1x1/weights
# import/MobilenetV1/Logits/Conv2d_1c_1x1/weights/read
# import/MobilenetV1/Logits/Conv2d_1c_1x1/biases
# import/MobilenetV1/Logits/Conv2d_1c_1x1/biases/read
# import/MobilenetV1/Logits/Conv2d_1c_1x1/convolution
# import/MobilenetV1/Logits/Conv2d_1c_1x1/BiasAdd
# import/MobilenetV1/Logits/SpatialSqueeze
# import/MobilenetV1/Predictions/Reshape/shape
# import/MobilenetV1/Predictions/Reshape
# import/input_1/BottleneckInputPlaceholder
# import/final_training_ops/weights/final_weights
# import/final_training_ops/weights/final_weights/read
# import/final_training_ops/biases/final_biases
# import/final_training_ops/biases/final_biases/read
# import/final_training_ops/Wx_plus_b/MatMul
# import/final_training_ops/Wx_plus_b/add
# import/final_result
